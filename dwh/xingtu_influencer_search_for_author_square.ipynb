# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
from pprint import pprint
import pandas as pd
import json
import copy
from datetime import datetime, timezone
from google.cloud import storage
import gcsfs
import re

# %%
storage_client = storage.Client(project="ytone-430507")
bucket = storage_client.bucket("3_staging_area")
today = datetime.now()
table_name = "douyin_influencer"
api_name = "search_for_author_square"
file_name = "xingtu_basic"

# %%
processing_blobs = [
{
    "blob": blob,
    "date": datetime.strptime(blob.name.split('/')[1], "%Y-%m-%d"),
    "batch_number": int(blob.name.split('/')[-1].replace(".json", "").split("_")[-1]),
} for blob in storage_client.list_blobs("0_raw_data",prefix="2_xingtu/") if file_name in blob.name]
processing_blobs
# Out:
# [{'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-07/xingtu_basic_240907_0.json, 1725791792735542>,
#   'date': datetime.datetime(2024, 9, 7, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_0.json, 1725800931531139>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_1.json, 1725800934868643>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_2.json, 1725800937650829>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_3.json, 1725800941091533>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_4.json, 1725800945109037>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-08/xingtu_basic_240908_5.json, 1725800951331873>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_0.json, 1728018276414764>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_1.json, 1728018280221017>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_10.json, 1728018284619836>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 10},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_11.json, 1728018288850861>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 11},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_12.json, 1728018292931517>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 12},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_13.json, 1728018297589058>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 13},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_14.json, 1728018302166357>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 14},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_15.json, 1728018306190998>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 15},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_16.json, 1728018310378061>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 16},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_17.json, 1728018314611675>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 17},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_18.json, 1728018318498109>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 18},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_19.json, 1728018322510035>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 19},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_2.json, 1728018326510634>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_20.json, 1728018330257664>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 20},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_21.json, 1728018334457188>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 21},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_22.json, 1728018338415987>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 22},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_23.json, 1728018342615649>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 23},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_24.json, 1728018346536223>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 24},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_25.json, 1728018350437467>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 25},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_26.json, 1728018354491063>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 26},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_27.json, 1728018358838214>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 27},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_28.json, 1728018361676923>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 28},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_3.json, 1728018365434102>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_4.json, 1728018369643387>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_5.json, 1728018374019252>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_6.json, 1728018377944805>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 6},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_7.json, 1728018381950648>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 7},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_8.json, 1728018386062483>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 8},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/xingtu_basic_241002_9.json, 1728018390299812>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 9}]

# %%
processed_blobs = [{
    "blob": blob,
    "date": datetime.strptime(blob.name.split('/')[2], "%Y-%m-%d"),
    "batch_number": int(blob.name.split('/')[-1].replace(".parquet", "").split("_")[-1]),
} for blob in storage_client.list_blobs("3_staging_area",prefix="1_xingtu/") if table_name == blob.name.split("/")[1] and api_name in blob.name and len(blob.name.split("/")) == 4]
processed_blobs
# Out:
# [{'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-08/search_for_author_square_241004_0.parquet, 1728031831447964>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_0.parquet, 1728296556790576>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_1.parquet, 1728296876872193>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_10.parquet, 1728296883690546>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 10},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_11.parquet, 1728296890322348>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 11},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_12.parquet, 1728296897140915>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 12},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_13.parquet, 1728296904363029>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 13},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_14.parquet, 1728296911297487>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 14},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_15.parquet, 1728296917577811>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 15},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_16.parquet, 1728296923889753>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 16},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_17.parquet, 1728296931041193>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 17},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_18.parquet, 1728296939966676>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 18},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_19.parquet, 1728296948950400>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 19},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_2.parquet, 1728296962215557>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_20.parquet, 1728296968347728>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 20},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_21.parquet, 1728296975680209>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 21},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_22.parquet, 1728296982774259>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 22},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_23.parquet, 1728296988775827>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 23},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_24.parquet, 1728296995309398>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 24},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_25.parquet, 1728297000618722>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 25},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_26.parquet, 1728297004643738>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 26},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_27.parquet, 1728297009418285>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 27},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_28.parquet, 1728297012559842>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 28},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_3.parquet, 1728297018495483>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_4.parquet, 1728297027059960>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_5.parquet, 1728297036365856>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_6.parquet, 1728297048136976>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 6},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_7.parquet, 1728297072486053>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 7},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_8.parquet, 1728297112135149>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 8},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/search_for_author_square_241007_9.parquet, 1728297126128339>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 9}]

# %%
to_process = []
for processing_blob in processing_blobs:
    if processing_blob["date"] >= datetime(2024, 10, 2):
        if processing_blob["batch_number"] not in [processed_blob["batch_number"] for processed_blob in processed_blobs if processing_blob["date"] == processed_blob["date"]]:
            to_process.append(processing_blob)
pprint(to_process)
print(len(to_process))
# Out:
# []
# 0

# %%
def get_basic_raw_data(item):
    attribute_datas = []
    basic_data = json.loads(item["blob"].download_as_string())
    for data in basic_data:
        for author_data in data["authors"]:
            attribute_datas.append(author_data["attribute_datas"])
    return attribute_datas

# %%
blob = bucket.blob("1_xingtu/author_options.json")
author_options = json.loads(blob.download_as_string())
pprint(author_options)
# Out:
# {'code': 0,
#  'data': {'author_gpm': [{'author_gpm__ge': 150},
#                          {'author_gpm__ge': 100, 'author_gpm__le': 150},
#                          {'author_gpm__ge': 50, 'author_gpm__le': 100},
#                          {'author_gpm__ge': 30, 'author_gpm__le': 50},
#                          {'author_gpm__ge': 10, 'author_gpm__le': 30},
#                          {'author_gpm__ge': 5, 'author_gpm__le': 10},
#                          {'author_gpm__le': 5}],
#           'avg_sale_amount': [{'avg_sale_amount__ge': 100000000},
#                               {'avg_sale_amount__ge': 50000000,
#                                'avg_sale_amount__le': 100000000},
#                               {'avg_sale_amount__ge': 10000000,
#                                'avg_sale_amount__le': 50000000},
#                               {'avg_sale_amount__ge': 5000000,
#                                'avg_sale_amount__le': 10000000},
#                               {'avg_sale_amount__ge': 1000000,
#                                'avg_sale_amount__le': 5000000},
#                               {'avg_sale_amount__ge': 500000,
#                                'avg_sale_amount__le': 1000000},
#                               {'avg_sale_amount__ge': 100000,
#                                'avg_sale_amount__le': 500000},
#                               {'avg_sale_amount__ge': 50000,
#                                'avg_sale_amount__le': 100000},
#                               {'avg_sale_amount__ge': 10000,
#                                'avg_sale_amount__le': 50000},
#                               {'avg_sale_amount__ge': 5000,
#                                'avg_sale_amount__le': 10000},
#                               {'avg_sale_amount__ge': 1000,
#                                'avg_sale_amount__le': 5000},
#                               {'avg_sale_amount__ge': 500,
#                                'avg_sale_amount__le': 1000},
#                               {'avg_sale_amount__le': 500}],
#           'aweme_label': [{'label': '财经', 'value': 669},
#                           {'label': '其他', 'value': 313},
#                           {'label': '户外', 'value': 312},
#                           {'label': '明星', 'value': 311},
#                           {'label': '创意', 'value': 310},
#                           {'label': '美食', 'value': 333},
#                           {'label': '随拍', 'value': 314},
#                           {'label': '汽车', 'value': 335},
#                           {'label': '旅行', 'value': 334},
#                           {'label': '娱乐', 'value': 337},
#                           {'label': '剧情', 'value': 308},
#                           {'label': '图文控', 'value': 309},
#                           {'label': '科技', 'value': 336},
#                           {'label': '三农', 'value': 718},
#                           {'label': '文化教育', 'value': 300},
#                           {'label': '校园', 'value': 301},
#                           {'label': '游戏', 'value': 302},
#                           {'label': '时尚', 'value': 305},
#                           {'label': '才艺', 'value': 306},
#                           {'label': '动植物', 'value': 307},
#                           {'label': '亲子', 'value': 315},
#                           {'label': '体育', 'value': 298},
#                           {'label': '泛生活', 'value': 299},
#                           {'label': '二次元', 'value': 296},
#                           {'label': '政务', 'value': 297}],
#           'content_tag_v2': [{'first': {'1': '美妆'},
#                               'second': [{'2': '美妆教程'},
#                                          {'3': '妆容展示'},
#                                          {'4': '护肤保养'},
#                                          {'5': '美妆测评种草'}]},
#                              {'first': {'6': '时尚'},
#                               'second': [{'7': '穿搭'},
#                                          {'8': '街拍'},
#                                          {'10': '造型'},
#                                          {'135': '时尚媒体'}]},
#                              {'first': {'11': '萌宠'},
#                               'second': [{'12': '日常宠物'},
#                                          {'13': '特别宠物'},
#                                          {'14': '宠物周边'}]},
#                              {'first': {'15': '测评'},
#                               'second': [{'16': '美妆测评'},
#                                          {'17': '3C数码测评'},
#                                          {'18': '汽车测评'},
#                                          {'19': '美食产品测评'},
#                                          {'20': '母婴产品测评'},
#                                          {'21': '综合测评'},
#                                          {'132': '酒店测评'}]},
#                              {'first': {'23': '游戏'},
#                               'second': [{'121': '游戏剧情'},
#                                          {'122': '游戏解说'},
#                                          {'123': '游戏资讯'},
#                                          {'124': '游戏其他'},
#                                          {'440': '游戏录屏'},
#                                          {'441': '游戏集锦'}]},
#                              {'first': {'25': '二次元'},
#                               'second': [{'125': '二次元真人'},
#                                          {'126': '动画漫画'},
#                                          {'127': '配音声优'},
#                                          {'128': '宅物手办'}]},
#                              {'first': {'27': '旅行'},
#                               'second': [{'28': '旅行记录'},
#                                          {'29': '旅行攻略'},
#                                          {'30': '旅行推荐'},
#                                          {'442': '户外生活'}]},
#                              {'first': {'31': '汽车'},
#                               'second': [{'32': '汽车测评'},
#                                          {'33': '汽车知识'},
#                                          {'34': '汽车周边'}]},
#                              {'first': {'36': '生活'},
#                               'second': [{'37': '生活记录'},
#                                          {'39': '生活小窍门'},
#                                          {'40': '好物推荐'},
#                                          {'118': '健康养生'},
#                                          {'422': '婚恋'}]},
#                              {'first': {'41': '音乐'},
#                               'second': [{'42': '歌曲演唱'},
#                                          {'43': '乐器演奏'},
#                                          {'44': '音乐教学'},
#                                          {'45': '音乐其他'},
#                                          {'136': '音乐剪辑'}]},
#                              {'first': {'46': '舞蹈'}, 'second': []},
#                              {'first': {'48': '美食'},
#                               'second': [{'49': '美食教程'},
#                                          {'50': '美食探店'},
#                                          {'52': '美食产品测评'},
#                                          {'53': '乡村野食'},
#                                          {'54': '美食其他'},
#                                          {'423': '酒类'}]},
#                              {'first': {'55': '母婴亲子'},
#                               'second': [{'56': '育儿科普'},
#                                          {'57': '萌娃日常'},
#                                          {'58': '亲子互动'},
#                                          {'59': '测评种草'}]},
#                              {'first': {'60': '运动健身'},
#                               'second': [{'61': '健身'},
#                                          {'63': '极限运动'},
#                                          {'424': '体育资讯'},
#                                          {'443': '冰雪'},
#                                          {'444': '垂钓'},
#                                          {'445': '格斗'},
#                                          {'446': '球类项目'},
#                                          {'447': '综合体育'}]},
#                              {'first': {'64': '科技数码'},
#                               'second': [{'65': '3C数码'},
#                                          {'66': '家居电器'},
#                                          {'133': '科技'}]},
#                              {'first': {'68': '教育培训'},
#                               'second': [{'69': '考学培训'},
#                                          {'70': '语言教学'},
#                                          {'71': '个人管理'},
#                                          {'425': '职业教育'}]},
#                              {'first': {'72': '颜值达人'},
#                               'second': [{'73': '美女'}, {'74': '帅哥'}]},
#                              {'first': {'1001': '生活家居'},
#                               'second': [{'100101': '硬装'},
#                                          {'100102': '软装'},
#                                          {'100103': '生活技巧'},
#                                          {'100104': '家居氛围'}]},
#                              {'first': {'79': '才艺技能'},
#                               'second': [{'80': '创意才能'},
#                                          {'81': '手工'},
#                                          {'82': '摄影'},
#                                          {'83': '绘画'},
#                                          {'84': '其他才艺'}]},
#                              {'first': {'85': '影视娱乐'},
#                               'second': [{'413': '影视解说'},
#                                          {'414': '影视混剪'},
#                                          {'415': '明星资讯'},
#                                          {'416': '综艺解说'},
#                                          {'417': '综艺混剪'}]},
#                              {'first': {'87': '艺术文化'},
#                               'second': [{'88': '传统文化'},
#                                          {'89': '人文科普'},
#                                          {'90': '自然科学'}]},
#                              {'first': {'91': '财经投资'},
#                               'second': [{'92': '传统金融'},
#                                          {'93': '互联网金融'},
#                                          {'94': '财经知识'}]},
#                              {'first': {'95': '三农'}, 'second': []},
#                              {'first': {'97': '剧情搞笑'},
#                               'second': [{'98': '剧情'}, {'99': '搞笑'}]},
#                              {'first': {'100': '情感'}, 'second': []},
#                              {'first': {'102': '园艺'}, 'second': []},
#                              {'first': {'139': '房产'},
#                               'second': [{'140': '其他房产'},
#                                          {'437': '房产知识'},
#                                          {'439': '房产及投资'},
#                                          {'448': '楼盘评测'},
#                                          {'449': '楼市资讯'},
#                                          {'450': '租房'}]},
#                              {'first': {'130': '随拍'}, 'second': []}],
#           'download_category_type': [{'first': {'9004': '游戏'},
#                                       'second': [{'900401': '武侠仙侠'},
#                                                  {'900402': '都市'},
#                                                  {'900403': '魔幻'},
#                                                  {'900404': '西游'},
#                                                  {'900405': '二次元'},
#                                                  {'900406': '三国'},
#                                                  {'900407': '战争'},
#                                                  {'900408': '传奇'},
#                                                  {'900409': '射击'},
#                                                  {'900410': '综合游戏'}]},
#                                      {'first': {'9001': '工具类软件'},
#                                       'second': [{'900101': '陌生人交友'},
#                                                  {'900102': '婚恋服务'},
#                                                  {'900103': '下沉交友'},
#                                                  {'900104': '语音交友/陪玩'},
#                                                  {'900105': '直播'},
#                                                  {'900106': '新闻资讯'},
#                                                  {'900107': '手办盲盒'},
#                                                  {'900108': '综合社交'},
#                                                  {'900109': 'WiFi'},
#                                                  {'900110': '办公'},
#                                                  {'900111': '浏览器'},
#                                                  {'900112': '天气/日历'},
#                                                  {'900113': '主题壁纸'},
#                                                  {'900114': '手机助手'},
#                                                  {'900115': '相机/视频美化'},
#                                                  {'900116': '潮玩盲盒'},
#                                                  {'900117': '综合工具'}]},
#                                      {'first': {'9002': '通信'},
#                                       'second': [{'900201': '通信'}]},
#                                      {'first': {'9003': '传媒及内容'},
#                                       'second': [{'900301': '小说-付费阅读'},
#                                                  {'900302': '小说-免费阅读'},
#                                                  {'900303': '影视宣发'},
#                                                  {'900304': '潮玩盲盒'},
#                                                  {'900305': '图书'},
#                                                  {'900306': '视频APP'},
#                                                  {'900307': '权益卡'},
#                                                  {'900308': '综合文娱'}]}],
#           'ecom_video_num_30d': [{'ecom_video_num_30d__ge': 20},
#                                  {'ecom_video_num_30d__ge': 10},
#                                  {'ecom_video_num_30d__ge': 5},
#                                  {'ecom_video_num_30d__ge': 1}],
#           'expected_cpm': [{'expected_cpm__le': 10},
#                            {'expected_cpm__le': 20},
#                            {'expected_cpm__le': 30},
#                            {'expected_cpm__le': 50},
#                            {'expected_cpm__le': 100},
#                            {'expected_cpm__ge': 100}],
#           'expected_play_num': [{'expected_play_num__ge': 10000000},
#                                 {'expected_play_num__ge': 5000000,
#                                  'expected_play_num__le': 10000000},
#                                 {'expected_play_num__ge': 3000000,
#                                  'expected_play_num__le': 5000000},
#                                 {'expected_play_num__ge': 1000000,
#                                  'expected_play_num__le': 3000000},
#                                 {'expected_play_num__ge': 100000,
#                                  'expected_play_num__le': 1000000},
#                                 {'expected_play_num__le': 100000}],
#           'fans': [{'fans_min': 10000000},
#                    {'fans_max': 10000000, 'fans_min': 5000000},
#                    {'fans_max': 5000000, 'fans_min': 3000000},
#                    {'fans_max': 3000000, 'fans_min': 1000000},
#                    {'fans_max': 1000000, 'fans_min': 100000},
#                    {'fans_max': 100000}],
#           'fans_category': ['玩具乐器',
#                             '二手商品',
#                             '服饰内衣',
#                             '个护家清',
#                             '礼品文创',
#                             '智能家居',
#                             '生鲜',
#                             '美妆',
#                             '母婴宠物',
#                             '鲜花园艺',
#                             '本地生活',
#                             '食品饮料',
#                             '3C数码家电',
#                             '图书教育',
#                             '鞋靴箱包',
#                             '虚拟充值',
#                             '运动户外',
#                             '钟表配饰',
#                             '珠宝文玩',
#                             '奢侈品'],
#           'fans_max': 50000000,
#           'game_type': ['MOBA',
#                         '体育',
#                         '射击',
#                         '沙盒',
#                         '小游戏',
#                         '格斗',
#                         '动作',
#                         '生存',
#                         '角色扮演',
#                         '休闲',
#                         '竞速',
#                         '棋牌',
#                         '乙女',
#                         '策略',
#                         '音乐',
#                         'MMORPG',
#                         '抽卡',
#                         '恐怖',
#                         '卡牌',
#                         '模拟',
#                         '怀旧'],
#           'gender': [[1, '男'], [2, '女']],
#           'industry_tag': [{'first': '3C及电器',
#                             'second': ['消费类电子产品',
#                                        '其他3C及电器',
#                                        '手机',
#                                        '电脑',
#                                        '3C及电器电商',
#                                        '3C及电器线下零售',
#                                        '小家电',
#                                        '家电配件',
#                                        '大家电',
#                                        '3C数码配件']},
#                            {'first': '食品饮料',
#                             'second': ['烟',
#                                        '烟酒电商',
#                                        '烟酒线下零售',
#                                        '零食/坚果/特产',
#                                        '饮料冲调',
#                                        '乳制品及乳制品饮料',
#                                        '粮油米面/南北干货/调味品',
#                                        '生鲜',
#                                        '其他食用初级农产品',
#                                        '其他食品饮料',
#                                        '酒',
#                                        '食品饮料（非生鲜）电商',
#                                        '食品饮料（非生鲜）线下零售',
#                                        '生鲜电商',
#                                        '生鲜线下零售',
#                                        '茶叶',
#                                        '膳食营养品',
#                                        '传统滋补营养品']},
#                            {'first': '服装配饰',
#                             'second': ['其他服装配饰',
#                                        '服装配饰电商',
#                                        '服装配饰线下零售',
#                                        '内衣裤袜',
#                                        '奢侈品',
#                                        '珠宝玉石',
#                                        '钟表类',
#                                        '男鞋',
#                                        '童鞋',
#                                        '箱包',
#                                        '女鞋',
#                                        '男装',
#                                        'cosplay/二次元服饰',
#                                        '女装',
#                                        '运动服/休闲服装/运动鞋',
#                                        '童装',
#                                        '服饰配件',
#                                        '时尚配饰']},
#                            {'first': '医疗健康',
#                             'second': ['医疗机构',
#                                        '医疗器械',
#                                        '药品',
#                                        '保健品-国内',
#                                        '医疗周边服务',
#                                        '其他医疗',
#                                        '医疗综合服务平台',
#                                        '兽药',
#                                        '网上药店/医药电商',
#                                        '药店/医药线下零售',
#                                        '保健品-跨境',
#                                        '美容美体医疗器械']},
#                            {'first': '商务服务',
#                             'second': ['安全安保',
#                                        '包装印刷',
#                                        '中介服务',
#                                        '管理咨询',
#                                        '广告服务',
#                                        '会展服务',
#                                        '设计',
#                                        '会计税务',
#                                        '法律服务',
#                                        '人力资源服务',
#                                        '其他商务服务',
#                                        '代运营服务']},
#                            {'first': '本地服务',
#                             'second': ['生活服务综合平台',
#                                        '便民服务',
#                                        '家政服务',
#                                        '护养服务',
#                                        '摄影',
#                                        '美容美发',
#                                        '回收买卖',
#                                        '租赁服务',
#                                        '婚恋服务',
#                                        '配送服务',
#                                        '移民服务',
#                                        '情感咨询',
#                                        '其他本地服务',
#                                        '结婚服务',
#                                        '婚嫁平台']},
#                            {'first': '房地产',
#                             'second': ['房地产开发商',
#                                        '物业管理公司',
#                                        '其他房地产',
#                                        '房地产综合服务平台',
#                                        '房地产分销商/渠道机构']},
#                            {'first': '家居建材',
#                             'second': ['家装主材',
#                                        '家具',
#                                        '其他家居建材',
#                                        '家居百货',
#                                        '家装辅材',
#                                        '家居建材线下零售',
#                                        '家饰',
#                                        '装修设计及工程服务',
#                                        '家装平台',
#                                        '家装灯饰光源',
#                                        '家用五金',
#                                        '床上用品',
#                                        '居家布艺',
#                                        '家用电工']},
#                            {'first': '教育',
#                             'second': ['幼儿教育',
#                                        '中小学教育',
#                                        '学历教育',
#                                        '语言及留学',
#                                        '兴趣培训',
#                                        '职业技能',
#                                        '企业管理培训',
#                                        '特殊人群教育',
#                                        '职业资格考证培训',
#                                        '其他教育培训',
#                                        '新媒体运营培训',
#                                        '理财培训',
#                                        '智能教育',
#                                        '学习卡']},
#                            {'first': '出行旅游',
#                             'second': ['景点',
#                                        '酒店住宿',
#                                        'OTA（online travel Agent）',
#                                        '旅行社',
#                                        '航空公司',
#                                        '公路客运公司',
#                                        '邮轮',
#                                        '商旅票务代理',
#                                        '城市出行',
#                                        '其他出行旅游',
#                                        '外旅局']},
#                            {'first': '社会公共',
#                             'second': ['政府政务文化旅游',
#                                        '社会组织',
#                                        '宗教',
#                                        '其他社会公共',
#                                        '政府政务科教卫生',
#                                        '政府政务环境安全']},
#                            {'first': '游戏',
#                             'second': ['休闲游戏',
#                                        '棋牌桌游',
#                                        '角色扮演',
#                                        '体育竞技',
#                                        'MOBA',
#                                        '其他游戏',
#                                        '射击游戏',
#                                        '动作游戏',
#                                        'SLG',
#                                        '塔防游戏',
#                                        '模拟经营',
#                                        '卡牌游戏',
#                                        '音乐游戏',
#                                        '游戏平台',
#                                        '游戏助手/加速器']},
#                            {'first': '零售',
#                             'second': ['综合类2B电商',
#                                        '垂直类2B电商',
#                                        '综合类2C电商',
#                                        '跨境类2C电商',
#                                        '综合类线下零售',
#                                        '其他零售']},
#                            {'first': '交通工具',
#                             'second': ['飞机厂商',
#                                        '船舶厂商',
#                                        '摩托车厂商',
#                                        '非机动车厂商',
#                                        '功能性车辆厂商',
#                                        '其他交通工具',
#                                        '交通工具后市场',
#                                        '摩托车经销商',
#                                        '非机动车经销商']},
#                            {'first': '汽车',
#                             'second': ['汽车厂商',
#                                        '汽车经销商',
#                                        '二手车线下零售',
#                                        '汽车后市场',
#                                        '其他汽车',
#                                        '汽车综合服务平台',
#                                        '新车线下零售',
#                                        '汽车周边服务']},
#                            {'first': '农林牧畜渔',
#                             'second': ['农业',
#                                        '林业',
#                                        '渔业',
#                                        '畜牧业',
#                                        '农林服务',
#                                        '畜牧饲料/添加剂',
#                                        '农用物资',
#                                        '其他农林牧畜渔']},
#                            {'first': '化工及能源',
#                             'second': ['化工制品',
#                                        '危险化学品',
#                                        '食品化工材料',
#                                        '化工其它',
#                                        '燃料能源',
#                                        '电力能源',
#                                        '新能源',
#                                        '矿产资源',
#                                        '污染处理',
#                                        '废旧回收',
#                                        '节能',
#                                        '其他化工及能源']},
#                            {'first': '电子电工',
#                             'second': ['电子器件',
#                                        '仪器仪表',
#                                        '电工电气',
#                                        '电工机械',
#                                        '其他电子电工']},
#                            {'first': '机械设备',
#                             'second': ['通用机械设备',
#                                        '农林机械',
#                                        '矿产机械',
#                                        '建筑工程机械',
#                                        '化工机械',
#                                        '木材石材加工机械',
#                                        '机床机械',
#                                        '商用设备',
#                                        '基础机械',
#                                        '工具配件',
#                                        '食品机械',
#                                        '清洁通风设备',
#                                        '其他机械设备',
#                                        '机械设备线下零售']},
#                            {'first': '文体娱乐',
#                             'second': ['演出票务及周边',
#                                        '文化艺术收藏品',
#                                        '文具玩具礼品',
#                                        '乐器',
#                                        '室内娱乐',
#                                        '运动健身',
#                                        '体育用品',
#                                        '户外用品',
#                                        '体育赛事及场馆',
#                                        '彩票',
#                                        '户外娱乐',
#                                        '其他文体娱乐',
#                                        '文体娱乐电商',
#                                        '文体娱乐线下零售']},
#                            {'first': '传媒资讯',
#                             'second': ['传媒服务商',
#                                        '电视台',
#                                        '广播台',
#                                        '影视综艺音像制作',
#                                        '数字版权',
#                                        '网络视听',
#                                        '其他传媒资讯',
#                                        '资讯',
#                                        '在线小说',
#                                        '短剧']},
#                            {'first': '物流业',
#                             'second': ['快递物流',
#                                        '货运代理',
#                                        '特殊运输',
#                                        '物流基础设施',
#                                        '其他物流业']},
#                            {'first': '通信',
#                             'second': ['电信运营商', '虚拟运营商', '通信设备', '其他通信']},
#                            {'first': '金融业',
#                             'second': ['银行业',
#                                        '证券业',
#                                        '保险业',
#                                        '拍卖典当',
#                                        '基金',
#                                        '征信机构',
#                                        '其他金融业',
#                                        '另类投资',
#                                        '综合金融平台',
#                                        '金融理财培训',
#                                        '贷款服务',
#                                        '第三方支付',
#                                        '金融门户网站',
#                                        '期货']},
#                            {'first': '餐饮服务', 'second': ['餐厅', '饮品', '其他餐饮服务']},
#                            {'first': '工具类软件',
#                             'second': ['软件工具', '多媒体处理', '实用工具', '其他工具类软件']},
#                            {'first': '招商加盟',
#                             'second': ['招商加盟联展平台',
#                                        '生活用品加盟',
#                                        '生活服务加盟',
#                                        '服装配饰加盟',
#                                        '美容美发加盟',
#                                        '室内娱乐加盟',
#                                        '教育培训加盟',
#                                        '酒店加盟',
#                                        '餐食加盟',
#                                        '房产家居建材加盟',
#                                        '食品加盟',
#                                        '汽车产品加盟',
#                                        '互联网软件加盟',
#                                        '其他招商加盟',
#                                        '减肥加盟',
#                                        '饮品烘焙加盟',
#                                        '保健品加盟',
#                                        '酒加盟',
#                                        '商务服务加盟',
#                                        '大健康代加工招商']},
#                            {'first': '美妆',
#                             'second': ['高档化妆品',
#                                        '美妆工具',
#                                        '化妆品线下零售',
#                                        '化妆品电商',
#                                        '美妆特殊化妆品',
#                                        '护肤',
#                                        '彩妆',
#                                        '香水']},
#                            {'first': '母婴宠物',
#                             'second': ['宠物用品',
#                                        '母婴用品电商',
#                                        '母婴用品线下零售',
#                                        '宠物用品电商',
#                                        '宠物用品线下零售',
#                                        '母婴服装',
#                                        '孕产妇用品',
#                                        '婴儿玩具',
#                                        '其他母婴宠物',
#                                        '婴童用品',
#                                        '宠物食品',
#                                        '辅食/营养品/零食',
#                                        '奶粉',
#                                        '婴童尿裤',
#                                        '婴童洗护']},
#                            {'first': '日化',
#                             'second': ['特殊日化用品',
#                                        '日化用品线下零售',
#                                        '家庭护理品',
#                                        '其他日化用品',
#                                        '日化用品电商',
#                                        '日化洗护',
#                                        '日化纸品',
#                                        '日化口腔',
#                                        '日化特殊化妆品']},
#                            {'first': '实体书籍',
#                             'second': ['考试/教材/教辅/论文', '儿童读物/童书', '其他成人类书籍']},
#                            {'first': '社交通讯',
#                             'second': ['一般社交通讯',
#                                        '交友类社交通讯',
#                                        '婚恋社交通讯',
#                                        '其他社交通讯',
#                                        '泛娱乐社交通讯']}],
#           'industry_tag_v2': [{'first': {'1901': '3C及电器'},
#                                'second': [{'190101': '消费类电子产品'},
#                                           {'190103': '其他3C及电器'},
#                                           {'190104': '手机'},
#                                           {'190106': '电脑'},
#                                           {'190108': '3C及电器电商'},
#                                           {'190109': '3C及电器线下零售'},
#                                           {'190110': '小家电'},
#                                           {'190111': '家电配件'},
#                                           {'190112': '大家电'},
#                                           {'190113': '3C数码配件'}]},
#                               {'first': {'1903': '食品饮料'},
#                                'second': [{'190206': '烟'},
#                                           {'190215': '烟酒电商'},
#                                           {'190216': '烟酒线下零售'},
#                                           {'190301': '零食/坚果/特产'},
#                                           {'190302': '饮料冲调'},
#                                           {'190303': '乳制品及乳制品饮料'},
#                                           {'190304': '粮油米面/南北干货/调味品'},
#                                           {'190305': '生鲜'},
#                                           {'190307': '其他食用初级农产品'},
#                                           {'190309': '其他食品饮料'},
#                                           {'190310': '酒'},
#                                           {'190311': '食品饮料（非生鲜）电商'},
#                                           {'190312': '食品饮料（非生鲜）线下零售'},
#                                           {'190313': '生鲜电商'},
#                                           {'190314': '生鲜线下零售'},
#                                           {'190315': '茶叶'},
#                                           {'190317': '膳食营养品'},
#                                           {'190318': '传统滋补营养品'}]},
#                               {'first': {'1904': '服装配饰'},
#                                'second': [{'190409': '其他服装配饰'},
#                                           {'190410': '服装配饰电商'},
#                                           {'190411': '服装配饰线下零售'},
#                                           {'190412': '内衣裤袜'},
#                                           {'190416': '奢侈品'},
#                                           {'190417': '珠宝玉石'},
#                                           {'190418': '钟表类'},
#                                           {'190419': '男鞋'},
#                                           {'190420': '童鞋'},
#                                           {'190421': '箱包'},
#                                           {'190422': '女鞋'},
#                                           {'190423': '男装'},
#                                           {'190424': 'cosplay/二次元服饰'},
#                                           {'190425': '女装'},
#                                           {'190426': '运动服/休闲服装/运动鞋'},
#                                           {'190427': '童装'},
#                                           {'190428': '服饰配件'},
#                                           {'190429': '时尚配饰'}]},
#                               {'first': {'1905': '医疗健康'},
#                                'second': [{'190501': '医疗机构'},
#                                           {'190503': '医疗器械'},
#                                           {'190504': '药品'},
#                                           {'190505': '保健品-国内'},
#                                           {'190506': '医疗周边服务'},
#                                           {'190507': '其他医疗'},
#                                           {'190508': '医疗综合服务平台'},
#                                           {'190509': '兽药'},
#                                           {'190510': '网上药店/医药电商'},
#                                           {'190511': '药店/医药线下零售'},
#                                           {'190512': '保健品-跨境'},
#                                           {'190513': '美容美体医疗器械'}]},
#                               {'first': {'1906': '商务服务'},
#                                'second': [{'190601': '安全安保'},
#                                           {'190603': '包装印刷'},
#                                           {'190604': '中介服务'},
#                                           {'190605': '管理咨询'},
#                                           {'190606': '广告服务'},
#                                           {'190607': '会展服务'},
#                                           {'190608': '设计'},
#                                           {'190609': '会计税务'},
#                                           {'190610': '法律服务'},
#                                           {'190611': '人力资源服务'},
#                                           {'190612': '其他商务服务'},
#                                           {'190613': '代运营服务'}]},
#                               {'first': {'1907': '本地服务'},
#                                'second': [{'190701': '生活服务综合平台'},
#                                           {'190702': '便民服务'},
#                                           {'190703': '家政服务'},
#                                           {'190704': '护养服务'},
#                                           {'190705': '摄影'},
#                                           {'190706': '美容美发'},
#                                           {'190707': '回收买卖'},
#                                           {'190708': '租赁服务'},
#                                           {'190710': '婚恋服务'},
#                                           {'190711': '配送服务'},
#                                           {'190712': '移民服务'},
#                                           {'190713': '情感咨询'},
#                                           {'190714': '其他本地服务'},
#                                           {'190715': '结婚服务'},
#                                           {'190716': '婚嫁平台'}]},
#                               {'first': {'1908': '房地产'},
#                                'second': [{'190801': '房地产开发商'},
#                                           {'190803': '物业管理公司'},
#                                           {'190805': '其他房地产'},
#                                           {'190806': '房地产综合服务平台'},
#                                           {'190807': '房地产分销商/渠道机构'}]},
#                               {'first': {'1909': '家居建材'},
#                                'second': [{'190901': '家装主材'},
#                                           {'190904': '家具'},
#                                           {'190906': '其他家居建材'},
#                                           {'190907': '家居百货'},
#                                           {'190909': '家装辅材'},
#                                           {'190913': '家居建材线下零售'},
#                                           {'190914': '家饰'},
#                                           {'190916': '装修设计及工程服务'},
#                                           {'190917': '家装平台'},
#                                           {'190919': '家装灯饰光源'},
#                                           {'190920': '家用五金'},
#                                           {'190921': '床上用品'},
#                                           {'190922': '居家布艺'},
#                                           {'190923': '家用电工'}]},
#                               {'first': {'1910': '教育'},
#                                'second': [{'191001': '幼儿教育'},
#                                           {'191002': '中小学教育'},
#                                           {'191003': '学历教育'},
#                                           {'191004': '语言及留学'},
#                                           {'191005': '兴趣培训'},
#                                           {'191006': '职业技能'},
#                                           {'191007': '企业管理培训'},
#                                           {'191008': '特殊人群教育'},
#                                           {'191009': '职业资格考证培训'},
#                                           {'191010': '其他教育培训'},
#                                           {'191011': '新媒体运营培训'},
#                                           {'191012': '理财培训'},
#                                           {'191013': '智能教育'},
#                                           {'191014': '学习卡'}]},
#                               {'first': {'1911': '出行旅游'},
#                                'second': [{'191101': '景点'},
#                                           {'191102': '酒店住宿'},
#                                           {'191103': 'OTA（online travel '
#                                                      'Agent）'},
#                                           {'191104': '旅行社'},
#                                           {'191105': '航空公司'},
#                                           {'191106': '公路客运公司'},
#                                           {'191107': '邮轮'},
#                                           {'191108': '商旅票务代理'},
#                                           {'191109': '城市出行'},
#                                           {'191110': '其他出行旅游'},
#                                           {'191111': '外旅局'}]},
#                               {'first': {'1912': '社会公共'},
#                                'second': [{'191201': '政府政务文化旅游'},
#                                           {'191202': '社会组织'},
#                                           {'191204': '宗教'},
#                                           {'191205': '其他社会公共'},
#                                           {'191206': '政府政务科教卫生'},
#                                           {'191207': '政府政务环境安全'}]},
#                               {'first': {'1913': '游戏'},
#                                'second': [{'191301': '休闲游戏'},
#                                           {'191302': '棋牌桌游'},
#                                           {'191303': '角色扮演'},
#                                           {'191305': '体育竞技'},
#                                           {'191308': 'MOBA'},
#                                           {'191309': '其他游戏'},
#                                           {'191310': '射击游戏'},
#                                           {'191311': '动作游戏'},
#                                           {'191312': 'SLG'},
#                                           {'191313': '塔防游戏'},
#                                           {'191314': '模拟经营'},
#                                           {'191315': '卡牌游戏'},
#                                           {'191316': '音乐游戏'},
#                                           {'191317': '游戏平台'},
#                                           {'191318': '游戏助手/加速器'}]},
#                               {'first': {'1914': '零售'},
#                                'second': [{'191401': '综合类2B电商'},
#                                           {'191402': '垂直类2B电商'},
#                                           {'191403': '综合类2C电商'},
#                                           {'191404': '跨境类2C电商'},
#                                           {'191406': '综合类线下零售'},
#                                           {'191408': '其他零售'}]},
#                               {'first': {'1915': '交通工具'},
#                                'second': [{'191501': '飞机厂商'},
#                                           {'191502': '船舶厂商'},
#                                           {'191503': '摩托车厂商'},
#                                           {'191504': '非机动车厂商'},
#                                           {'191505': '功能性车辆厂商'},
#                                           {'191506': '其他交通工具'},
#                                           {'191507': '交通工具后市场'},
#                                           {'191508': '摩托车经销商'},
#                                           {'191509': '非机动车经销商'}]},
#                               {'first': {'1916': '汽车'},
#                                'second': [{'191601': '汽车厂商'},
#                                           {'191602': '汽车经销商'},
#                                           {'191603': '二手车线下零售'},
#                                           {'191604': '汽车后市场'},
#                                           {'191605': '其他汽车'},
#                                           {'191606': '汽车综合服务平台'},
#                                           {'191607': '新车线下零售'},
#                                           {'191608': '汽车周边服务'}]},
#                               {'first': {'1917': '农林牧畜渔'},
#                                'second': [{'191701': '农业'},
#                                           {'191702': '林业'},
#                                           {'191703': '渔业'},
#                                           {'191704': '畜牧业'},
#                                           {'191705': '农林服务'},
#                                           {'191706': '畜牧饲料/添加剂'},
#                                           {'191707': '农用物资'},
#                                           {'191708': '其他农林牧畜渔'}]},
#                               {'first': {'1918': '化工及能源'},
#                                'second': [{'191801': '化工制品'},
#                                           {'191803': '危险化学品'},
#                                           {'191804': '食品化工材料'},
#                                           {'191805': '化工其它'},
#                                           {'191806': '燃料能源'},
#                                           {'191807': '电力能源'},
#                                           {'191808': '新能源'},
#                                           {'191809': '矿产资源'},
#                                           {'191810': '污染处理'},
#                                           {'191811': '废旧回收'},
#                                           {'191812': '节能'},
#                                           {'191813': '其他化工及能源'}]},
#                               {'first': {'1919': '电子电工'},
#                                'second': [{'191901': '电子器件'},
#                                           {'191902': '仪器仪表'},
#                                           {'191903': '电工电气'},
#                                           {'191904': '电工机械'},
#                                           {'191905': '其他电子电工'}]},
#                               {'first': {'1920': '机械设备'},
#                                'second': [{'192001': '通用机械设备'},
#                                           {'192002': '农林机械'},
#                                           {'192003': '矿产机械'},
#                                           {'192004': '建筑工程机械'},
#                                           {'192005': '化工机械'},
#                                           {'192006': '木材石材加工机械'},
#                                           {'192007': '机床机械'},
#                                           {'192008': '商用设备'},
#                                           {'192009': '基础机械'},
#                                           {'192010': '工具配件'},
#                                           {'192011': '食品机械'},
#                                           {'192013': '清洁通风设备'},
#                                           {'192014': '其他机械设备'},
#                                           {'192015': '机械设备线下零售'}]},
#                               {'first': {'1921': '文体娱乐'},
#                                'second': [{'192101': '演出票务及周边'},
#                                           {'192102': '文化艺术收藏品'},
#                                           {'192103': '文具玩具礼品'},
# ...
#                                          {'label': '油皮', 'value': '110403'},
#                                          {'label': '敏感肌', 'value': '110404'},
#                                          {'label': '痘痘肌', 'value': '110405'},
#                                          {'label': '黄皮', 'value': '110406'},
#                                          {'label': '白皮', 'value': '110407'},
#                                          {'label': '瑕疵皮', 'value': '110408'}],
#                             'label': '肤质肤色',
#                             'value': '1104'},
#                            {'children': [{'label': '美白', 'value': '110501'},
#                                          {'label': '抗老', 'value': '110502'},
#                                          {'label': '祛皱', 'value': '110503'},
#                                          {'label': '抗炎', 'value': '110504'},
#                                          {'label': '修复', 'value': '110505'},
#                                          {'label': '控油', 'value': '110506'},
#                                          {'label': '眼部护理', 'value': '110507'},
#                                          {'label': '补水保湿', 'value': '110508'},
#                                          {'label': '祛斑', 'value': '110509'},
#                                          {'label': '祛痘祛闭口', 'value': '110510'},
#                                          {'label': '隔离防晒', 'value': '110511'}],
#                             'label': '皮肤养护',
#                             'value': '1105'},
#                            {'children': [{'label': '婴儿期一段', 'value': '110601'},
#                                          {'label': '婴儿期二段', 'value': '110602'},
#                                          {'label': '幼儿期', 'value': '110603'},
#                                          {'label': '学龄期+', 'value': '110604'},
#                                          {'label': '怀孕期', 'value': '110605'},
#                                          {'label': '备孕期', 'value': '110606'}],
#                             'label': '母婴阶段',
#                             'value': '1106'},
#                            {'children': [{'label': '潮流运动', 'value': '110701'}],
#                             'label': '时尚穿搭',
#                             'value': '1107'},
#                            {'children': [{'label': '球类', 'value': '110801'},
#                                          {'label': '非球类', 'value': '110802'}],
#                             'label': '体育达人',
#                             'value': '1108'},
#                            {'children': [{'label': '室内健身', 'value': '110901'},
#                                          {'label': '城市运动', 'value': '110902'},
#                                          {'label': '户外运动', 'value': '110903'}],
#                             'label': '运动场景',
#                             'value': '1109'},
#                            {'label': '数码潮流玩家', 'value': '1110'},
#                            {'label': '户外爱好者', 'value': '1111'},
#                            {'label': '室内设计师', 'value': '1112'},
#                            {'label': '品酒家/调酒师', 'value': '1113'},
#                            {'label': '美食评论人', 'value': '1114'},
#                            {'label': '专业美食从业者', 'value': '1115'},
#                            {'label': '母婴行业专家', 'value': '1116'},
#                            {'label': '奶爸', 'value': '1118'},
#                            {'label': '旧屋改造', 'value': '1119'},
#                            {'label': '装修设计', 'value': '1120'},
#                            {'label': '收纳', 'value': '1121'},
#                            {'label': '新生儿妈妈', 'value': '1122'},
#                            {'label': '孕妈', 'value': '1123'},
#                            {'label': '时尚妈妈', 'value': '1124'},
#                            {'label': '二三胎妈妈', 'value': '1125'},
#                            {'label': '西餐', 'value': '1126'},
#                            {'label': '火锅', 'value': '1127'},
#                            {'label': '国风爱好者', 'value': '1128'},
#                            {'label': '成分党', 'value': '1129'},
#                            {'children': [{'label': '摄影', 'value': '110204'},
#                                          {'label': '时尚穿搭', 'value': '110205'},
#                                          {'label': '美食制作', 'value': '110209'},
#                                          {'label': '科普', 'value': '110215'},
#                                          {'label': '星座', 'value': '110217'},
#                                          {'label': '绘画', 'value': '110221'}],
#                             'label': '爱好',
#                             'value': '1130'},
#                            {'children': [{'label': '法律从业者', 'value': '110216'},
#                                          {'label': '航空业从业者', 'value': '110218'},
#                                          {'label': '健身/舞蹈教练',
#                                           'value': '110219'},
#                                          {'label': '专业美食从业者',
#                                           'value': '113101'},
#                                          {'label': '室内设计师', 'value': '113102'}],
#                             'label': '职业',
#                             'value': '1131'},
#                            {'children': [{'label': '大学生', 'value': '110213'},
#                                          {'label': '硕士生', 'value': '110211'},
#                                          {'label': '博士', 'value': '110212'},
#                                          {'label': '留学生', 'value': '110214'}],
#                             'label': '学历',
#                             'value': '1133'},
#                            {'children': [{'label': '美妆创作者', 'value': '110201'},
#                                          {'label': '体育创作者', 'value': '110203'},
#                                          {'label': '媒体人/主持人',
#                                           'value': '110207'},
#                                          {'label': '科技创作者', 'value': '110210'},
#                                          {'label': '运动员', 'value': '110220'}],
#                             'label': '黄v认证',
#                             'value': '1134'}],
#           'price': [{'price_min': 100000},
#                     {'price_max': 100000, 'price_min': 50000},
#                     {'price_max': 50000, 'price_min': 10000},
#                     {'price_max': 10000, 'price_min': 5000},
#                     {'price_max': 5000, 'price_min': 2000},
#                     {'price_max': 2000}],
#           'price_max': 1000000,
#           'style_tag': [{'106': 'vlog'},
#                         {'107': '古风'},
#                         {'108': '街头采访'},
#                         {'109': '知识'},
#                         {'110': '海外'},
#                         {'111': '探店'},
#                         {'112': '户外'},
#                         {'113': '外国人'},
#                         {'114': '情侣cp'},
#                         {'115': '技术流'},
#                         {'116': '后期特效'},
#                         {'117': '动画'}],
#           'tag': [{'first': {'1': '美妆'},
#                    'second': [{'2': '美妆教程'},
#                               {'3': '妆容展示'},
#                               {'4': '护肤保养'},
#                               {'5': '美妆测评种草'}]},
#                   {'first': {'6': '时尚'},
#                    'second': [{'7': '穿搭'},
#                               {'8': '街拍'},
#                               {'10': '造型'},
#                               {'135': '时尚媒体'}]},
#                   {'first': {'11': '萌宠'},
#                    'second': [{'12': '日常宠物'}, {'13': '特别宠物'}, {'14': '宠物周边'}]},
#                   {'first': {'15': '测评'},
#                    'second': [{'16': '美妆测评'},
#                               {'17': '3C数码测评'},
#                               {'18': '汽车测评'},
#                               {'19': '美食产品测评'},
#                               {'20': '母婴产品测评'},
#                               {'21': '综合测评'},
#                               {'132': '酒店测评'}]},
#                   {'first': {'23': '游戏'},
#                    'second': [{'121': '游戏剧情'},
#                               {'122': '游戏解说'},
#                               {'123': '游戏资讯'},
#                               {'124': '游戏其他'},
#                               {'440': '游戏录屏'},
#                               {'441': '游戏集锦'}]},
#                   {'first': {'25': '二次元'},
#                    'second': [{'125': '二次元真人'},
#                               {'126': '动画漫画'},
#                               {'127': '配音声优'},
#                               {'128': '宅物手办'}]},
#                   {'first': {'27': '旅行'},
#                    'second': [{'28': '旅行记录'},
#                               {'29': '旅行攻略'},
#                               {'30': '旅行推荐'},
#                               {'442': '户外生活'}]},
#                   {'first': {'31': '汽车'},
#                    'second': [{'32': '汽车测评'}, {'33': '汽车知识'}, {'34': '汽车周边'}]},
#                   {'first': {'36': '生活'},
#                    'second': [{'37': '生活记录'},
#                               {'39': '生活小窍门'},
#                               {'40': '好物推荐'},
#                               {'118': '健康养生'},
#                               {'422': '婚恋'}]},
#                   {'first': {'41': '音乐'},
#                    'second': [{'42': '歌曲演唱'},
#                               {'43': '乐器演奏'},
#                               {'44': '音乐教学'},
#                               {'45': '音乐其他'},
#                               {'136': '音乐剪辑'}]},
#                   {'first': {'46': '舞蹈'}, 'second': []},
#                   {'first': {'48': '美食'},
#                    'second': [{'49': '美食教程'},
#                               {'50': '美食探店'},
#                               {'52': '美食产品测评'},
#                               {'53': '乡村野食'},
#                               {'54': '美食其他'},
#                               {'423': '酒类'}]},
#                   {'first': {'55': '母婴亲子'},
#                    'second': [{'56': '育儿科普'},
#                               {'57': '萌娃日常'},
#                               {'58': '亲子互动'},
#                               {'59': '测评种草'}]},
#                   {'first': {'60': '运动健身'},
#                    'second': [{'61': '健身'},
#                               {'63': '极限运动'},
#                               {'424': '体育资讯'},
#                               {'443': '冰雪'},
#                               {'444': '垂钓'},
#                               {'445': '格斗'},
#                               {'446': '球类项目'},
#                               {'447': '综合体育'}]},
#                   {'first': {'64': '科技数码'},
#                    'second': [{'65': '3C数码'}, {'66': '家居电器'}, {'133': '科技'}]},
#                   {'first': {'68': '教育培训'},
#                    'second': [{'69': '考学培训'},
#                               {'70': '语言教学'},
#                               {'71': '个人管理'},
#                               {'425': '职业教育'}]},
#                   {'first': {'72': '颜值达人'},
#                    'second': [{'73': '美女'}, {'74': '帅哥'}]},
#                   {'first': {'1001': '生活家居'},
#                    'second': [{'100101': '硬装'},
#                               {'100102': '软装'},
#                               {'100103': '生活技巧'},
#                               {'100104': '家居氛围'}]},
#                   {'first': {'79': '才艺技能'},
#                    'second': [{'80': '创意才能'},
#                               {'81': '手工'},
#                               {'82': '摄影'},
#                               {'83': '绘画'},
#                               {'84': '其他才艺'}]},
#                   {'first': {'85': '影视娱乐'},
#                    'second': [{'413': '影视解说'},
#                               {'414': '影视混剪'},
#                               {'415': '明星资讯'},
#                               {'416': '综艺解说'},
#                               {'417': '综艺混剪'}]},
#                   {'first': {'87': '艺术文化'},
#                    'second': [{'88': '传统文化'}, {'89': '人文科普'}, {'90': '自然科学'}]},
#                   {'first': {'91': '财经投资'},
#                    'second': [{'92': '传统金融'}, {'93': '互联网金融'}, {'94': '财经知识'}]},
#                   {'first': {'95': '三农'}, 'second': []},
#                   {'first': {'97': '剧情搞笑'},
#                    'second': [{'98': '剧情'}, {'99': '搞笑'}]},
#                   {'first': {'100': '情感'}, 'second': []},
#                   {'first': {'102': '园艺'}, 'second': []},
#                   {'first': {'139': '房产'},
#                    'second': [{'140': '其他房产'},
#                               {'437': '房产知识'},
#                               {'439': '房产及投资'},
#                               {'448': '楼盘评测'},
#                               {'449': '楼市资讯'},
#                               {'450': '租房'}]},
#                   {'first': {'130': '随拍'}, 'second': []}],
#           'tonality_label': [{'children': [{'label': '马术', 'value': 1060101},
#                                            {'label': '高尔夫', 'value': 1060102},
#                                            {'label': '橄榄球', 'value': 1060103},
#                                            {'label': '时尚爱好者', 'value': 1060104},
#                                            {'label': '企业高管', 'value': 1060105},
#                                            {'label': '汽车爱好者', 'value': 1060106},
#                                            {'label': '学者专家', 'value': 1060107},
#                                            {'label': '古玩收藏', 'value': 1060108}],
#                               'label': '身份/爱好',
#                               'value': 10601},
#                              {'children': [{'label': '设计师', 'value': 1060201},
#                                            {'label': '高阶潮玩', 'value': 1060203},
#                                            {'label': '职业模特', 'value': 1060204},
#                                            {'label': '造型顾问', 'value': 1060205},
#                                            {'label': '独立设计师', 'value': 1060206},
#                                            {'label': '美术/画廊/展览',
#                                             'value': 1060207},
#                                            {'label': '歌剧舞台剧', 'value': 1060208},
#                                            {'label': '流行', 'value': 1060209},
#                                            {'label': '潮流买手', 'value': 1060210},
#                                            {'label': '电影', 'value': 1060212}],
#                               'label': '精致达人',
#                               'value': 10602},
#                              {'children': [{'label': '冲浪', 'value': 1060301},
#                                            {'label': '浮潜', 'value': 1060302},
#                                            {'label': '说唱', 'value': 1060303},
#                                            {'label': '滑雪', 'value': 1060304},
#                                            {'label': '普拉提', 'value': 1060305},
#                                            {'label': '网球', 'value': 1060306}],
#                               'label': '潮流酷',
#                               'value': 10603}],
#           'video_types': [1, 2, 71],
#           'watcher_age': [{'label': '小于18岁居多', 'value': 37},
#                           {'label': '18-23岁居多', 'value': 38},
#                           {'label': '24-30岁居多', 'value': 39},
#                           {'label': '31-40岁居多', 'value': 40},
#                           {'label': '41-50岁居多', 'value': 41},
#                           {'label': '大于50岁居多', 'value': 42}],
#           'watcher_city': [{'label': '一线城市居多', 'value': 48},
#                            {'label': '二线城市居多', 'value': 49},
#                            {'label': '三线城市居多', 'value': 50},
#                            {'label': '四线城市居多', 'value': 51},
#                            {'label': '五线城市居多', 'value': 52}],
#           'watcher_device': [{'label': '苹果居多', 'value': 43},
#                              {'label': '华为居多', 'value': 44},
#                              {'label': '小米居多', 'value': 45},
#                              {'label': 'vivo居多', 'value': 46},
#                              {'label': 'oppo居多', 'value': 47}],
#           'watcher_gender': [{'label': '全部', 'value': 0},
#                              {'label': '男', 'value': 1},
#                              {'label': '女', 'value': 2}]},
#  'msg': '成功'}

# %%
tags = author_options["data"]["tag"]
pprint(tags)
# Out:
# [{'first': {'1': '美妆'},
#   'second': [{'2': '美妆教程'}, {'3': '妆容展示'}, {'4': '护肤保养'}, {'5': '美妆测评种草'}]},
#  {'first': {'6': '时尚'},
#   'second': [{'7': '穿搭'}, {'8': '街拍'}, {'10': '造型'}, {'135': '时尚媒体'}]},
#  {'first': {'11': '萌宠'},
#   'second': [{'12': '日常宠物'}, {'13': '特别宠物'}, {'14': '宠物周边'}]},
#  {'first': {'15': '测评'},
#   'second': [{'16': '美妆测评'},
#              {'17': '3C数码测评'},
#              {'18': '汽车测评'},
#              {'19': '美食产品测评'},
#              {'20': '母婴产品测评'},
#              {'21': '综合测评'},
#              {'132': '酒店测评'}]},
#  {'first': {'23': '游戏'},
#   'second': [{'121': '游戏剧情'},
#              {'122': '游戏解说'},
#              {'123': '游戏资讯'},
#              {'124': '游戏其他'},
#              {'440': '游戏录屏'},
#              {'441': '游戏集锦'}]},
#  {'first': {'25': '二次元'},
#   'second': [{'125': '二次元真人'},
#              {'126': '动画漫画'},
#              {'127': '配音声优'},
#              {'128': '宅物手办'}]},
#  {'first': {'27': '旅行'},
#   'second': [{'28': '旅行记录'}, {'29': '旅行攻略'}, {'30': '旅行推荐'}, {'442': '户外生活'}]},
#  {'first': {'31': '汽车'},
#   'second': [{'32': '汽车测评'}, {'33': '汽车知识'}, {'34': '汽车周边'}]},
#  {'first': {'36': '生活'},
#   'second': [{'37': '生活记录'},
#              {'39': '生活小窍门'},
#              {'40': '好物推荐'},
#              {'118': '健康养生'},
#              {'422': '婚恋'}]},
#  {'first': {'41': '音乐'},
#   'second': [{'42': '歌曲演唱'},
#              {'43': '乐器演奏'},
#              {'44': '音乐教学'},
#              {'45': '音乐其他'},
#              {'136': '音乐剪辑'}]},
#  {'first': {'46': '舞蹈'}, 'second': []},
#  {'first': {'48': '美食'},
#   'second': [{'49': '美食教程'},
#              {'50': '美食探店'},
#              {'52': '美食产品测评'},
#              {'53': '乡村野食'},
#              {'54': '美食其他'},
#              {'423': '酒类'}]},
#  {'first': {'55': '母婴亲子'},
#   'second': [{'56': '育儿科普'}, {'57': '萌娃日常'}, {'58': '亲子互动'}, {'59': '测评种草'}]},
#  {'first': {'60': '运动健身'},
#   'second': [{'61': '健身'},
#              {'63': '极限运动'},
#              {'424': '体育资讯'},
#              {'443': '冰雪'},
#              {'444': '垂钓'},
#              {'445': '格斗'},
#              {'446': '球类项目'},
#              {'447': '综合体育'}]},
#  {'first': {'64': '科技数码'},
#   'second': [{'65': '3C数码'}, {'66': '家居电器'}, {'133': '科技'}]},
#  {'first': {'68': '教育培训'},
#   'second': [{'69': '考学培训'}, {'70': '语言教学'}, {'71': '个人管理'}, {'425': '职业教育'}]},
#  {'first': {'72': '颜值达人'}, 'second': [{'73': '美女'}, {'74': '帅哥'}]},
#  {'first': {'1001': '生活家居'},
#   'second': [{'100101': '硬装'},
#              {'100102': '软装'},
#              {'100103': '生活技巧'},
#              {'100104': '家居氛围'}]},
#  {'first': {'79': '才艺技能'},
#   'second': [{'80': '创意才能'},
#              {'81': '手工'},
#              {'82': '摄影'},
#              {'83': '绘画'},
#              {'84': '其他才艺'}]},
#  {'first': {'85': '影视娱乐'},
#   'second': [{'413': '影视解说'},
#              {'414': '影视混剪'},
#              {'415': '明星资讯'},
#              {'416': '综艺解说'},
#              {'417': '综艺混剪'}]},
#  {'first': {'87': '艺术文化'},
#   'second': [{'88': '传统文化'}, {'89': '人文科普'}, {'90': '自然科学'}]},
#  {'first': {'91': '财经投资'},
#   'second': [{'92': '传统金融'}, {'93': '互联网金融'}, {'94': '财经知识'}]},
#  {'first': {'95': '三农'}, 'second': []},
#  {'first': {'97': '剧情搞笑'}, 'second': [{'98': '剧情'}, {'99': '搞笑'}]},
#  {'first': {'100': '情感'}, 'second': []},
#  {'first': {'102': '园艺'}, 'second': []},
#  {'first': {'139': '房产'},
#   'second': [{'140': '其他房产'},
#              {'437': '房产知识'},
#              {'439': '房产及投资'},
#              {'448': '楼盘评测'},
#              {'449': '楼市资讯'},
#              {'450': '租房'}]},
#  {'first': {'130': '随拍'}, 'second': []}]

# %%
def get_search_for_author_square_data(raw_data):
    search_for_author_square_data = []
    for data in raw_data:
        record = {}
        profile_id = data.get("id")
        record["user_id"] = profile_id
        record["nickname"] = data.get("nick_name")
        record["image_url"] = data.get("avatar_uri")
        record["fans_count"] = data.get("follower")
        record["city"] = data.get("city")
        record["province"] = data.get("province")
        record["expected_play_num"] = data.get("expected_play_num")
        record["sex"] = data.get("gender")
        prices = []
        price_1_20 = data.get("price_1_20")
        if price_1_20:
            prices.append(price_1_20)
        price_20_60 = data.get("price_20_60")
        if price_20_60:
            prices.append(price_20_60)
        price_60 = data.get("price_60")
        if price_60:
            prices.append(price_60)
        if prices:
            record["lowest_price"] = min(prices)
        record["e_commerce_enable"] = data.get("e_commerce_enable")
        tags_relation = data.get("tags_relation")
        if tags_relation:
            tags_relation = json.loads(data.get("tags_relation"))
            tags_id = []
            tags_ids_level_two = []
            for tag_1, tag_2 in tags_relation.items():
                for tag in tags:
                    first_tag = tag["first"]
                    for key, value in first_tag.items():
                        if tag_1 == value:
                            tags_id.append(key)
                            second_tag = tag["second"]
                            for tag_2_value in tag_2:
                                for item in second_tag:
                                    for key, value in item.items():
                                        if tag_2_value == value:
                                            tags_ids_level_two.append(key)
            record["tags_ids"] = "{" + ",".join(tags_id) + "}"
            record["tags_ids_level_two"] = "{" + ",".join(tags_ids_level_two) + "}"
        record["core_user_id"] = data.get("core_user_id")
        search_for_author_square_data.append(record)
    return search_for_author_square_data

# %%
for item in to_process:
    raw_data = get_basic_raw_data(item)
    search_for_author_square_data = get_search_for_author_square_data(raw_data)
    df = pd.DataFrame(search_for_author_square_data)
    df.to_parquet("gs://3_staging_area/1_xingtu/douyin_influencer/" + str(item["date"].date()) + "/" + api_name + "_" + today.strftime("%y%m%d") + "_" + str(item["batch_number"]) + ".parquet")
