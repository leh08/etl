# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
from pprint import pprint
import pandas as pd
import json
import copy
from datetime import datetime, timezone
from google.cloud import storage
import gcsfs
import re

# %%
storage_client = storage.Client(project="ytone-430507")
today = datetime.now()
table_name = "douyin_influencer"
api_name = "handler_post"

# %%
processing_blobs = [
{
    "blob": blob,
    "date": datetime.strptime(blob.name.split('/')[1], "%Y-%m-%d"),
    "batch_number": int(blob.name.split('/')[-1].replace(".json", "").split("_")[-1]),
} for blob in storage_client.list_blobs("0_raw_data",prefix="2_xingtu/") if api_name in blob.name]
processing_blobs
# Out:
# [{'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-11/handler_post_0911_0.json, 1726037777115120>,
#   'date': datetime.datetime(2024, 9, 11, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_0.json, 1726117857045627>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_1.json, 1726117860404297>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_10.json, 1726124693780255>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 10},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_2.json, 1726117863832561>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_3.json, 1726117867242406>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_4.json, 1726124673548605>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_5.json, 1726124676889778>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_6.json, 1726124680204384>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 6},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_7.json, 1726124683627615>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 7},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_8.json, 1726124687047359>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 8},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-12/handler_post_0912_9.json, 1726124690457839>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 9},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-13/handler_post_0913_0.json, 1726206442220451>,
#   'date': datetime.datetime(2024, 9, 13, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-09-13/handler_post_0913_1.json, 1726206444493761>,
#   'date': datetime.datetime(2024, 9, 13, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_0.json, 1728374609443157>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_1.json, 1728374610386372>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_2.json, 1728034755688119>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_3.json, 1728034759155460>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_4.json, 1728034762611464>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-02/handler_post_241002_5.json, 1728034763948709>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-06/handler_post_241002_0.json, 1728374750060460>,
#   'date': datetime.datetime(2024, 10, 6, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-06/handler_post_241006_0.json, 1728375117895827>,
#   'date': datetime.datetime(2024, 10, 6, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-09/handler_post_1009_0.json, 1728476127085324>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-09/handler_post_1009_1.json, 1728476132168822>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-09/handler_post_1009_2.json, 1728476135267968>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-10/handler_post_1010_0.json, 1728547750052288>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-10/handler_post_1010_1.json, 1728547755093818>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-10/handler_post_1010_2.json, 1728547756945216>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_0.json, 1728633838334445>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_1.json, 1728633842027146>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_2.json, 1728633842581655>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-30/handler_post_1030_0.json, 1728384144207030>,
#   'date': datetime.datetime(2024, 10, 30, 0, 0),
#   'batch_number': 0}]

# %%
processed_blobs = [{
    "blob": blob,
    "date": datetime.strptime(blob.name.split('/')[2], "%Y-%m-%d"),
    "batch_number": int(blob.name.split('/')[-1].replace(".parquet", "").split("_")[-1]),
} for blob in storage_client.list_blobs("3_staging_area",prefix="1_xingtu/") if table_name == blob.name.split("/")[1] and api_name in blob.name and len(blob.name.split("/")) == 4]
processed_blobs
# Out:
# [{'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-08/handler_post_240925_0.parquet, 1727254211218380>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-08/handler_post_240925_1.parquet, 1727254725202112>,
#   'date': datetime.datetime(2024, 9, 8, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-09/handler_post_240925_0.parquet, 1727255249211724>,
#   'date': datetime.datetime(2024, 9, 9, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-11/handler_post_240926_0.parquet, 1727321361381190>,
#   'date': datetime.datetime(2024, 9, 11, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_0.parquet, 1727261138070930>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_1.parquet, 1727261141343448>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_10.parquet, 1727261160108842>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 10},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_2.parquet, 1727261164754911>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_3.parquet, 1727261173770305>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_4.parquet, 1727261178367554>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_5.parquet, 1727261183188846>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_6.parquet, 1727261188924051>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 6},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_7.parquet, 1727261194051326>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 7},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_8.parquet, 1727261197652357>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 8},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-12/handler_post_240925_9.parquet, 1727261200904370>,
#   'date': datetime.datetime(2024, 9, 12, 0, 0),
#   'batch_number': 9},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-13/handler_post_240925_0.parquet, 1727261203988991>,
#   'date': datetime.datetime(2024, 9, 13, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-09-13/handler_post_240925_1.parquet, 1727261206711166>,
#   'date': datetime.datetime(2024, 9, 13, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_0.parquet, 1728530571643197>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_1.parquet, 1728530573706007>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_2.parquet, 1728530575986285>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_3.parquet, 1728530579093555>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 3},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_4.parquet, 1728530582216645>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 4},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-02/handler_post_241010_5.parquet, 1728530584305998>,
#   'date': datetime.datetime(2024, 10, 2, 0, 0),
#   'batch_number': 5},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-06/handler_post_241010_0.parquet, 1728530588274633>,
#   'date': datetime.datetime(2024, 10, 6, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-09/handler_post_241010_0.parquet, 1728530591540960>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-09/handler_post_241010_1.parquet, 1728530594602144>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-09/handler_post_241010_2.parquet, 1728530597074085>,
#   'date': datetime.datetime(2024, 10, 9, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-10/handler_post_241010_0.parquet, 1728555577860816>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 0},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-10/handler_post_241010_1.parquet, 1728555580717620>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 1},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-10/handler_post_241010_2.parquet, 1728555582435145>,
#   'date': datetime.datetime(2024, 10, 10, 0, 0),
#   'batch_number': 2},
#  {'blob': <Blob: 3_staging_area, 1_xingtu/douyin_influencer/2024-10-30/handler_post_241010_0.parquet, 1728493130050981>,
#   'date': datetime.datetime(2024, 10, 30, 0, 0),
#   'batch_number': 0}]

# %%
to_process = []
for processing_blob in processing_blobs:
    if processing_blob["date"] >= datetime(2024, 9, 12):
        if processing_blob["batch_number"] not in [processed_blob["batch_number"] for processed_blob in processed_blobs if processing_blob["date"] == processed_blob["date"]]:
            to_process.append(processing_blob)
pprint(to_process)
print(len(to_process))
# Out:
# [{'batch_number': 0,
#   'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_0.json, 1728633838334445>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0)},
#  {'batch_number': 1,
#   'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_1.json, 1728633842027146>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0)},
#  {'batch_number': 2,
#   'blob': <Blob: 0_raw_data, 2_xingtu/2024-10-11/handler_post_1011_2.json, 1728633842581655>,
#   'date': datetime.datetime(2024, 10, 11, 0, 0)}]
# 3

# %%
def get_handler_post_data(raw_data):
    result = []
    for data in raw_data:
        record = {}
        profile_id = data["profile_id"]
        handler_post = data.get("handler_post")
        if handler_post:
            overall_score = handler_post.get("overall_score")
            if overall_score:
                score = overall_score.get("score")
                if score:
                    record["influencer_id"] = profile_id
                    record["order_complete_cnt"] = overall_score["finish_order_cnt"]
                    record["cooperate_index"] = score["cooperate_index"]
                    record["shopping_index"] = score["shopping_index"]
                    record["spread_index"] = score["spread_index"]
                    record["top_score"] = score["top_score"]
                    record["cp_index"] = score["cp_index"]
                    result.append(record)
    return result

# %%
for item in to_process:
    raw_data = json.loads(item["blob"].download_as_string())
    handler_post_data = get_handler_post_data(raw_data)
    df = pd.DataFrame(handler_post_data)
    df.to_parquet("gs://3_staging_area/1_xingtu/douyin_influencer/" + str(item["date"].date()) + "/" + api_name + "_" + today.strftime("%y%m%d") + "_" + str(item["batch_number"]) + ".parquet")
