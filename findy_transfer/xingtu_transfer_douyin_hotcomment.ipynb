# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import json
import copy
from datetime import datetime, timezone
from google.cloud import storage
import gcsfs
import re
from sqlalchemy import create_engine, text
from typing import List

# %%
postgres_config = {
    "host": "findy-medium-stage.czmgcqkw4ett.ap-southeast-1.rds.amazonaws.com",
    "database": "findy_medium_stage",
    "user": "postgres",
    "password": "F!nDy!Med!umStage2o24",
    "port": "5432"
}

# %%
def build_upsert_query(cols: List[str],
                       table_name: str,
                       unique_key: List[str]=[],
                       cols_not_for_update: List[str] = None) -> str:
    """
    Builds postgres upsert query using input arguments.
    Note: In the absence of unique_key, this will be just an insert query.
    Example : build_upsert_query(
        ['col1', 'col2', 'col3', 'col4'],
        "my_table",
        ['col1'],
        ['col2']
    ) ->
    INSERT INTO my_table (col1, col2, col3, col4) VALUES %s
    ON CONFLICT (col1) DO UPDATE SET (col3, col4) = (EXCLUDED.col3, EXCLUDED.col4) ;
    :param cols: the postgres table columns required in the
        insert part of the query.
    :param table_name: the postgres table name.
    :param unique_key: unique_key of the postgres table for checking
        unique constraint violations.
    :param cols_not_for_update: columns in cols which are not required in
        the update part of upsert query.
    :return: Upsert query as per input arguments.
    """
    cols = [f'"{col}"' for col in cols]
    cols_str = ', '.join(cols)
    insert_query = """ INSERT INTO %s (%s) VALUES %%s """ % (
        table_name, cols_str
    )
    if cols_not_for_update is not None:
        cols_not_for_update.extend(unique_key)
    else:
        cols_not_for_update = [col for col in unique_key]
    cols_not_for_update = [f'"{col}"' for col in cols_not_for_update]
    unique_key = [f'"{col}"' for col in unique_key]
    unique_key_str = ', '.join(unique_key)

    update_cols = [f"{col}" for col in cols if col not in cols_not_for_update]
    update_cols_str = ', '.join(update_cols)
    update_cols_with_excluded_markers = [f'EXCLUDED.{col}' for col in update_cols]
    update_cols_with_excluded_markers_str = ', '.join(
        update_cols_with_excluded_markers
    )
    if len(update_cols) > 1:
        equality_clause = "(%s) = (%s)"
    else:
        equality_clause = "%s = %s"

    on_conflict_clause = f""" ON CONFLICT (%s) DO UPDATE SET {equality_clause} ;"""
    on_conflict_clause = on_conflict_clause % (
        unique_key_str,
        update_cols_str,
        update_cols_with_excluded_markers_str
    )
    if len(unique_key) == 0:
        return insert_query
    return insert_query + on_conflict_clause

# %%
storage_client = storage.Client(project="ytone-430507")
today = datetime.now()
table_name = "douyin_hotcomment"
bucket_name = "4_data_warehouse"

# %%
processing_blobs = [
{
    "blob": blob,
    "date": blob.name.split('/')[2],
    "batch": int(blob.name.split('/')[-1].replace(".parquet", "").split("_")[-1]),
} for blob in storage_client.list_blobs(bucket_name,prefix="1_xingtu/" + table_name + "/") if blob.name.endswith(".parquet")]
processing_blobs
# Out:
# [{'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-08/douyin_hotcomment_240917_0.parquet, 1726568052386224>,
#   'date': '2024-09-08',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-08/douyin_hotcomment_240917_1.parquet, 1726568151807526>,
#   'date': '2024-09-08',
#   'batch': 1},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-09/douyin_hotcomment_240917_0.parquet, 1726550714121472>,
#   'date': '2024-09-09',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-11/douyin_hotcomment_240917_0.parquet, 1726550690740629>,
#   'date': '2024-09-11',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_0.parquet, 1726565331570382>,
#   'date': '2024-09-13',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_1.parquet, 1726550616090291>,
#   'date': '2024-09-13',
#   'batch': 1},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_2.parquet, 1726550630391599>,
#   'date': '2024-09-13',
#   'batch': 2},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_3.parquet, 1726550647894869>,
#   'date': '2024-09-13',
#   'batch': 3},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_4.parquet, 1726565333423700>,
#   'date': '2024-09-13',
#   'batch': 4},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-17/douyin_hotcomment_240917_0.parquet, 1726565501921528>,
#   'date': '2024-09-17',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-18/douyin_hotcomment_240918_0.parquet, 1726653606493625>,
#   'date': '2024-09-18',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-09-19/douyin_hotcomment_240919_0.parquet, 1726722008220085>,
#   'date': '2024-09-19',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_0.parquet, 1728533843833780>,
#   'date': '2024-10-09',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_1.parquet, 1728533893494670>,
#   'date': '2024-10-09',
#   'batch': 1},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_2.parquet, 1728533895153785>,
#   'date': '2024-10-09',
#   'batch': 2},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_241009_0.parquet, 1728533844960816>,
#   'date': '2024-10-09',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_0.parquet, 1728556006999146>,
#   'date': '2024-10-10',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_1.parquet, 1728556008679592>,
#   'date': '2024-10-10',
#   'batch': 1},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_10.parquet, 1728556010303509>,
#   'date': '2024-10-10',
#   'batch': 10},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_11.parquet, 1728556012092065>,
#   'date': '2024-10-10',
#   'batch': 11},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_12.parquet, 1728556013753950>,
#   'date': '2024-10-10',
#   'batch': 12},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_13.parquet, 1728556015473624>,
#   'date': '2024-10-10',
#   'batch': 13},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_14.parquet, 1728556017105447>,
#   'date': '2024-10-10',
#   'batch': 14},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_15.parquet, 1728556018716047>,
#   'date': '2024-10-10',
#   'batch': 15},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_16.parquet, 1728556020355885>,
#   'date': '2024-10-10',
#   'batch': 16},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_17.parquet, 1728556022043727>,
#   'date': '2024-10-10',
#   'batch': 17},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_18.parquet, 1728556023650886>,
#   'date': '2024-10-10',
#   'batch': 18},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_19.parquet, 1728556025161111>,
#   'date': '2024-10-10',
#   'batch': 19},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_2.parquet, 1728556026803456>,
#   'date': '2024-10-10',
#   'batch': 2},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_3.parquet, 1728556028385314>,
#   'date': '2024-10-10',
#   'batch': 3},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_4.parquet, 1728556030047622>,
#   'date': '2024-10-10',
#   'batch': 4},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_5.parquet, 1728556031669006>,
#   'date': '2024-10-10',
#   'batch': 5},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_6.parquet, 1728556033237145>,
#   'date': '2024-10-10',
#   'batch': 6},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_7.parquet, 1728556034899809>,
#   'date': '2024-10-10',
#   'batch': 7},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_8.parquet, 1728556036596237>,
#   'date': '2024-10-10',
#   'batch': 8},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_9.parquet, 1728556038011843>,
#   'date': '2024-10-10',
#   'batch': 9},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_0.parquet, 1728639204272477>,
#   'date': '2024-10-11',
#   'batch': 0},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_1.parquet, 1728639205955557>,
#   'date': '2024-10-11',
#   'batch': 1},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_10.parquet, 1728638662375654>,
#   'date': '2024-10-11',
#   'batch': 10},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_11.parquet, 1728638663836124>,
#   'date': '2024-10-11',
#   'batch': 11},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_2.parquet, 1728638665612686>,
#   'date': '2024-10-11',
#   'batch': 2},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_3.parquet, 1728638667274740>,
#   'date': '2024-10-11',
#   'batch': 3},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_4.parquet, 1728638668890347>,
#   'date': '2024-10-11',
#   'batch': 4},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_5.parquet, 1728638670671083>,
#   'date': '2024-10-11',
#   'batch': 5},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_6.parquet, 1728638672633456>,
#   'date': '2024-10-11',
#   'batch': 6},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_7.parquet, 1728638674211584>,
#   'date': '2024-10-11',
#   'batch': 7},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_8.parquet, 1728638675830001>,
#   'date': '2024-10-11',
#   'batch': 8},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_9.parquet, 1728638677637241>,
#   'date': '2024-10-11',
#   'batch': 9},
#  {'blob': <Blob: 4_data_warehouse, 1_xingtu/douyin_hotcomment/2024-10-30/douyin_hotcomment_241009_0.parquet, 1728457606296767>,
#   'date': '2024-10-30',
#   'batch': 0}]

# %%
bucket = storage_client.get_bucket(bucket_name)
meta_blob = bucket.blob("1_xingtu/" + table_name + "/meta.json")
if meta_blob.exists():
    processed_blobs = json.loads(meta_blob.download_as_string())
else:
    processed_blobs = []
processed_blobs
# Out:
# [{'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_0.parquet',
#   'date': '2024-10-09',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_1.parquet',
#   'date': '2024-10-09',
#   'batch': 1},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_1009_2.parquet',
#   'date': '2024-10-09',
#   'batch': 2},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-09/douyin_hotcomment_241009_0.parquet',
#   'date': '2024-10-09',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-30/douyin_hotcomment_241009_0.parquet',
#   'date': '2024-10-30',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_0.parquet',
#   'date': '2024-10-10',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_1.parquet',
#   'date': '2024-10-10',
#   'batch': 1},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_10.parquet',
#   'date': '2024-10-10',
#   'batch': 10},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_11.parquet',
#   'date': '2024-10-10',
#   'batch': 11},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_12.parquet',
#   'date': '2024-10-10',
#   'batch': 12},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_13.parquet',
#   'date': '2024-10-10',
#   'batch': 13},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_14.parquet',
#   'date': '2024-10-10',
#   'batch': 14},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_15.parquet',
#   'date': '2024-10-10',
#   'batch': 15},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_16.parquet',
#   'date': '2024-10-10',
#   'batch': 16},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_17.parquet',
#   'date': '2024-10-10',
#   'batch': 17},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_18.parquet',
#   'date': '2024-10-10',
#   'batch': 18},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_19.parquet',
#   'date': '2024-10-10',
#   'batch': 19},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_2.parquet',
#   'date': '2024-10-10',
#   'batch': 2},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_3.parquet',
#   'date': '2024-10-10',
#   'batch': 3},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_4.parquet',
#   'date': '2024-10-10',
#   'batch': 4},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_5.parquet',
#   'date': '2024-10-10',
#   'batch': 5},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_6.parquet',
#   'date': '2024-10-10',
#   'batch': 6},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_7.parquet',
#   'date': '2024-10-10',
#   'batch': 7},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_8.parquet',
#   'date': '2024-10-10',
#   'batch': 8},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-10/douyin_hotcomment_1010_9.parquet',
#   'date': '2024-10-10',
#   'batch': 9},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-08/douyin_hotcomment_240917_0.parquet',
#   'date': '2024-09-08',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-08/douyin_hotcomment_240917_1.parquet',
#   'date': '2024-09-08',
#   'batch': 1},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-09/douyin_hotcomment_240917_0.parquet',
#   'date': '2024-09-09',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-11/douyin_hotcomment_240917_0.parquet',
#   'date': '2024-09-11',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_0.parquet',
#   'date': '2024-09-13',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_1.parquet',
#   'date': '2024-09-13',
#   'batch': 1},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_2.parquet',
#   'date': '2024-09-13',
#   'batch': 2},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_3.parquet',
#   'date': '2024-09-13',
#   'batch': 3},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-13/douyin_hotcomment_240917_4.parquet',
#   'date': '2024-09-13',
#   'batch': 4},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-17/douyin_hotcomment_240917_0.parquet',
#   'date': '2024-09-17',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-18/douyin_hotcomment_240918_0.parquet',
#   'date': '2024-09-18',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-09-19/douyin_hotcomment_240919_0.parquet',
#   'date': '2024-09-19',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_10.parquet',
#   'date': '2024-10-11',
#   'batch': 10},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_11.parquet',
#   'date': '2024-10-11',
#   'batch': 11},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_2.parquet',
#   'date': '2024-10-11',
#   'batch': 2},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_3.parquet',
#   'date': '2024-10-11',
#   'batch': 3},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_4.parquet',
#   'date': '2024-10-11',
#   'batch': 4},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_5.parquet',
#   'date': '2024-10-11',
#   'batch': 5},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_6.parquet',
#   'date': '2024-10-11',
#   'batch': 6},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_7.parquet',
#   'date': '2024-10-11',
#   'batch': 7},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_8.parquet',
#   'date': '2024-10-11',
#   'batch': 8},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_9.parquet',
#   'date': '2024-10-11',
#   'batch': 9},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_0.parquet',
#   'date': '2024-10-11',
#   'batch': 0},
#  {'file_path': 'gs://4_data_warehouse/1_xingtu/douyin_hotcomment/2024-10-11/douyin_hotcomment_1011_1.parquet',
#   'date': '2024-10-11',
#   'batch': 1}]

# %%
to_process = []
for processing_blob in processing_blobs:
    processing_date = datetime.strptime(processing_blob["date"], "%Y-%m-%d")
    if processing_date >= datetime(2024, 10, 9):
        if processing_blob["batch"] not in [processed_blob["batch"] for processed_blob in processed_blobs if processing_blob["date"] == processed_blob["date"]]:
            to_process.append(processing_blob)
pprint(to_process)
print(len(to_process))
# Out:
# []
# 0

# %%
for item in to_process:
    engine = create_engine("postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(**postgres_config))
    l_df = pd.read_sql_table(table_name,con=engine)
    r_df = pd.read_parquet("gs://" + bucket_name + "/" + item["blob"].name)
    m_df = pd.read_sql_table("douyin_influencer",con=engine)
    df = pd.merge(m_df, r_df, left_on="user_id", right_on="influencer_id", how="inner")
    df = df[["id"] + [column for column in r_df.columns if "influencer_id" not in column]]
    upsert_df = df.rename(columns={"id": "influencer_id"})
    query = build_upsert_query(upsert_df.columns, table_name, ["influencer_id", "content"])
    value = ", ".join([str(record).replace("''", "NULL") for record in upsert_df.fillna("").to_records(index=False)])
    query = query % value
    with engine.connect() as conn:
        result = conn.execute(text(query))
        conn.commit()
    processed_blobs.append({
        'file_path': "gs://" + bucket_name + "/" + item["blob"].name,
        'date': item["date"],
        'batch': item["batch"]
    })
    meta_blob.upload_from_string(json.dumps(processed_blobs))
